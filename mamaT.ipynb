# %% [markdown]
# # MAMA  Tee   ML
# ## By  Gift  Ahmed

# %%
import  pandas  as  pd

# %%
df =  pd.read_csv('data/tips.csv')

# %%
df.head()
# Out:
#    total_bill     tip  gender smoker   day    time  size
# 0     2125.50  360.79    Male     No  Thur   Lunch     1
# 1     2727.18  259.42  Female     No   Sun  Dinner     5
# 2     1066.02  274.68  Female    Yes  Thur  Dinner     4
# 3     3493.45  337.90  Female     No   Sun  Dinner     1
# 4     3470.56  567.89    Male    Yes   Sun   Lunch     6

# %%
df.shape
# Out:
# (744, 7)

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  744 non-null    float64
#  1   tip         744 non-null    float64
#  2   gender      744 non-null    object
#  3   smoker      744 non-null    object
#  4   day         744 non-null    object
#  5   time        744 non-null    object
#  6   size        744 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.8+ KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe()
# Out:
#         total_bill          tip        size
# count   744.000000   744.000000  744.000000
# mean   2165.006640   325.948091    3.180108
# std     954.248806   148.778225    1.532890
# min      44.690000     0.000000    1.000000
# 25%    1499.022500   218.000000    2.000000
# 50%    2102.610000   320.460000    3.000000
# 75%    2743.802500   415.562500    4.000000
# max    5538.290000  1090.000000    6.000000

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
y =  df['tip']
X =  df.drop('tip',  axis = 1)

# %%
X
# Out:
#      total_bill  gender smoker   day    time  size
# 0       2125.50    Male     No  Thur   Lunch     1
# 1       2727.18  Female     No   Sun  Dinner     5
# 2       1066.02  Female    Yes  Thur  Dinner     4
# 3       3493.45  Female     No   Sun  Dinner     1
# 4       3470.56    Male    Yes   Sun   Lunch     6
# ..          ...     ...    ...   ...     ...   ...
# 739     3164.27    Male     No   Sat  Dinner     3
# 740     2962.62  Female    Yes   Sat  Dinner     2
# 741     2471.03    Male    Yes   Sat  Dinner     2
# 742     1942.38    Male     No   Sat  Dinner     2
# 743     2047.02  Female     No  Thur  Dinner     2
#
# [744 rows x 6 columns]

# %%
y
# Out:
# 0      360.79
# 1      259.42
# 2      274.68
# 3      337.90
# 4      567.89
#         ...
# 739    645.28
# 740    218.00
# 741    218.00
# 742    190.75
# 743    327.00
# Name: tip, Length: 744, dtype: float64

# %%
# Convert categorical features using OneHotEncoding
X = pd.get_dummies(X, drop_first=True)

# %%
X
# Out:
#      total_bill  size  gender_Male  smoker_Yes  day_Mon  day_Sat  day_Sun  \
# 0       2125.50     1         True       False    False    False    False
# 1       2727.18     5        False       False    False    False     True
# 2       1066.02     4        False        True    False    False    False
# 3       3493.45     1        False       False    False    False     True
# 4       3470.56     6         True        True    False    False     True
# ..          ...   ...          ...         ...      ...      ...      ...
# 739     3164.27     3         True       False    False     True    False
# 740     2962.62     2        False        True    False     True    False
# 741     2471.03     2         True        True    False     True    False
# 742     1942.38     2         True       False    False     True    False
# 743     2047.02     2        False       False    False    False    False
#
#      day_Thur  day_Tues  day_Wed  time_Lunch
# 0        True     False    False        True
# 1       False     False    False       False
# 2        True     False    False       False
# 3       False     False    False       False
# 4       False     False    False        True
# ..        ...       ...      ...         ...
# 739     False     False    False       False
# 740     False     False    False       False
# 741     False     False    False       False
# 742     False     False    False       False
# 743      True     False    False       False
#
# [744 rows x 11 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test) ## Predict
# Out:
# array([284.93390775, 352.64547677, 304.31140983, 372.63469626,
#        257.47764952, 329.17529311, 277.16221544, 360.51361322,
#        386.3372227 , 294.13324496, 337.81851363, 268.04706804,
#        283.70460701, 270.71919725, 285.78008631, 370.26465449,
#        233.65022922, 288.75823123, 350.65994414, 312.52757514,
#        316.39039668, 326.51410202, 326.88451523, 340.4913748 ,
#        282.09726182, 316.77743163, 333.43430841, 293.08556481,
#        270.02811104, 282.00729413, 362.68752764, 345.65683226,
#        333.1245882 , 322.27061817, 273.66893879, 309.22637724,
#        349.8130061 , 285.44005905, 243.3317666 , 407.06560164,
#        270.13335865, 297.75368064, 330.54232727, 383.83903682,
#        325.2475132 , 337.86608254, 327.57439039, 324.7102521 ,
#        287.73004508, 327.37002121, 301.73904689, 244.70997485,
#        328.72311852, 231.97824331, 306.37408264, 325.58667981,
#        376.90065057, 368.09662001, 265.18567916, 367.55288507,
#        341.50720543, 298.65662721, 274.55031869, 377.10749191,
#        336.95077958, 311.71417563, 251.97958888, 358.73272297,
#        228.64669049, 363.98121568, 326.73526983, 318.5854218 ,
#        302.20401792, 288.63504971, 420.03355129, 366.82486865,
#        286.19785688, 326.87162885, 286.85205529, 310.81231613,
#        276.67412044, 339.49858637, 294.50706355, 324.17724339,
#        384.53098621, 359.09045361, 339.10304445, 317.93122228,
#        304.14226923, 345.02404459, 377.79090709, 386.46085094,
#        338.88989792, 374.94984286, 260.42376796, 338.38440069,
#        290.59730748, 312.83400865, 295.89137824, 302.98401588,
#        323.25939569, 387.4848884 , 320.08905521, 353.75539148,
#        287.17656635, 326.07741277, 292.20553798, 344.36068736,
#        337.58666195, 371.23151506, 306.04173273, 309.53698393,
#        315.71048826, 324.40838137, 297.78649132, 327.67610439,
#        293.7492638 , 352.74987641, 332.59232367, 291.8354199 ,
#        247.34149646, 303.915204  , 280.47275135, 272.38401105,
#        325.43249901, 314.86939956, 286.10798749, 284.33872645,
#        294.72669941, 349.28640054, 313.93207   , 348.35699999,
#        315.27840772, 300.40426227, 266.29169341, 332.51259985,
#        287.3990279 , 313.79926191, 333.28107438, 326.91585369,
#        282.20459803, 268.39214715, 296.84589748, 315.63472835,
#        348.55044059, 381.04018375, 416.65283015, 372.056284  ,
#        300.95006364, 306.70919341, 281.50840481, 344.56750688,
#        268.89968715, 265.37817038, 297.02258131, 294.69488819,
#        257.25824658, 290.4844632 , 354.29576859, 321.59846358,
#        333.23776548, 376.82756026, 430.40013646, 371.7761371 ,
#        302.30431075, 276.04915059, 294.22297638, 281.53803206,
#        324.75038681, 300.22076209, 336.44521151, 302.33800328,
#        388.32784644, 280.64287261, 362.98039115, 297.4798249 ,
#        277.39568805, 353.753017  , 383.13761136, 353.30976628,
#        302.86724772, 316.39275321, 334.55466645, 328.91997454,
#        305.88634429, 367.56770729, 283.46643726, 312.35714258,
#        331.61410134, 354.09900198, 296.33073802, 305.62875787,
#        263.97202731, 324.91100749, 335.11382879, 315.52627199,
#        337.10314875, 364.41295254, 331.06994624, 319.54291351,
#        352.70193345, 329.66264914, 333.1326846 , 342.24875081,
#        362.71127082, 327.63434249, 374.73795971, 285.02180038,
#        248.79102082, 335.59919969, 363.93260212, 281.58245082,
#        344.29176624, 308.09071018, 416.44868465, 312.70225918,
#        371.13741398, 350.97750798, 322.64096344, 289.73764358,
#        336.34738952, 292.61435704, 345.22522191, 328.47121873])

# %%
from sklearn.metrics import mean_absolute_error

# TODO: Evaluate your model using the following
# - R Square/Adjusted R Square
# - Mean Square Error(MSE)/Root Mean Square Error(RMSE)
# - Mean Absolute Error(MAE)

y_pred = reg.predict(X_test)

print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 118.89702992837498

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Decision Tree
dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred_dt))
# Out:
# MAE 149.52464285714288

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Random Forest
rf = RandomForestRegressor(random_state=42, n_estimators=100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred_rf))
# Out:
# MAE 120.50495000000001

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
import numpy as np

# %%
results = pd.DataFrame({
    "Model": ["Linear Regression", "Decision Tree", "Random Forest"],
    "MAE": [
        mean_absolute_error(y_test, y_pred),
        mean_absolute_error(y_test, y_pred_dt),
        mean_absolute_error(y_test, y_pred_rf)
    ],
    "RMSE": [
        np.sqrt(mean_squared_error(y_test, y_pred)),
        np.sqrt(mean_squared_error(y_test, y_pred_dt)),
        np.sqrt(mean_squared_error(y_test, y_pred_rf))
    ],
    "R2 Score": [
        r2_score(y_test, y_pred),
        r2_score(y_test, y_pred_dt),
        r2_score(y_test, y_pred_rf)
    ]
})

print("\n===== Model Comparison Table =====")
print(results)
# Out:
# ===== Model Comparison Table =====
#                Model         MAE        RMSE  R2 Score
# 0  Linear Regression  118.897030  151.220741  0.015844
# 1      Decision Tree  149.524643  199.897517 -0.719713
# 2      Random Forest  120.504950  154.852847 -0.031999
